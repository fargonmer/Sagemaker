# %%
import pandas as pd

# %%
from sagemaker import get_execution_role
role=get_execution_role()
bucket='sagemaker-first1' #use the name of your bucket here

# %%
role
# Out:
# 'arn:aws:iam::338414223723:role/service-role/AmazonSageMaker-ExecutionRole-20200526T224497'

# %%
# %%time
import pickle, gzip, numpy, urllib.request, json

# Load the dataset
urllib.request.urlretrieve("http://deeplearning.net/data/mnist/mnist.pkl.gz", "mnist.pkl.gz")
with gzip.open('mnist.pkl.gz', 'rb') as f:
    train_set, valid_set, test_set = pickle.load(f, encoding='latin1')
# Out:
# CPU times: user 855 ms, sys: 331 ms, total: 1.19 s
# Wall time: 2.37 s

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (2,10)


def show_digit(img, caption='', subplot=None):
    if subplot == None:
        _, (subplot) = plt.subplots(1,1)
    imgr = img.reshape((28,28))
    subplot.axis('off')
    subplot.imshow(imgr, cmap='gray')
    plt.title(caption)

show_digit(train_set[0][1], 'This is a {}'.format(train_set[1][1]))

# %%
from sagemaker import KMeans

data_location = 's3://{}/kmeans_highlevel_example/data'.format(bucket)
output_location = 's3://{}/kmeans_highlevel_example/output'.format(bucket)

print('training data will be uploaded to: {}'.format(data_location))
print('training artifacts will be uploaded to: {}'.format(output_location))

kmeans = KMeans(role=role,
                train_instance_count=2,
                train_instance_type='ml.c4.8xlarge',
                output_path=output_location,
                k=10,
                epochs=100,
                data_location=data_location)
# Out:
# training data will be uploaded to: s3://sagemaker-first1/kmeans_highlevel_example/data
# training artifacts will be uploaded to: s3://sagemaker-first1/kmeans_highlevel_example/output

# %%
# %%time

kmeans.fit(kmeans.record_set(train_set[0]))
# Out:
# 2020-05-27 02:56:51 Starting - Starting the training job...
# 2020-05-27 02:56:53 Starting - Launching requested ML instances......
# 2020-05-27 02:57:55 Starting - Preparing the instances for training...
# 2020-05-27 02:58:47 Downloading - Downloading input data...
# 2020-05-27 02:59:19 Training - Downloading the training image..Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [05/27/2020 02:59:37 INFO 140049757583168] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'_enable_profiler': u'false', u'_tuning_objective_metric': u'', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'_kvstore': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'true', u'epochs': u'1', u'init_method': u'random', u'local_lloyd_tol': u'0.0001', u'local_lloyd_max_iter': u'300', u'_disable_wait_to_read': u'false', u'extra_center_factor': u'auto', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'half_life_time_size': u'0', u'_num_slices': u'1'}
# [05/27/2020 02:59:37 INFO 140049757583168] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'epochs': u'100', u'feature_dim': u'784', u'k': u'10', u'force_dense': u'True'}
# [05/27/2020 02:59:37 INFO 140049757583168] Final configuration: {u'_tuning_objective_metric': u'', u'extra_center_factor': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'True', u'epochs': u'100', u'feature_dim': u'784', u'local_lloyd_tol': u'0.0001', u'_disable_wait_to_read': u'false', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'_enable_profiler': u'false', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'init_method': u'random', u'half_life_time_size': u'0', u'local_lloyd_max_iter': u'300', u'_kvstore': u'auto', u'k': u'10', u'_num_slices': u'1'}
# [05/27/2020 02:59:37 WARNING 140049757583168] Loggers have already been setup.
# [05/27/2020 02:59:37 INFO 140049757583168] Launching parameter server for role scheduler
# [05/27/2020 02:59:37 INFO 140049757583168] {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/393acab1-4b1a-4ea1-8367-949922e9f99d', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/393acab1-4b1a-4ea1-8367-949922e9f99d', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'AWS_REGION': 'us-east-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'kmeans-2020-05-27-02-56-51-195', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '18', 'HOSTNAME': 'ip-10-0-80-194.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/d33e7c3e-3dd1-44e3-a8c0-35a73b5341ef', 'PWD': '/', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:338414223723:training-job/kmeans-2020-05-27-02-56-51-195', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [05/27/2020 02:59:37 INFO 140049757583168] envs={'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/393acab1-4b1a-4ea1-8367-949922e9f99d', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/393acab1-4b1a-4ea1-8367-949922e9f99d', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '2', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.80.194', 'AWS_REGION': 'us-east-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'kmeans-2020-05-27-02-56-51-195', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '18', 'HOSTNAME': 'ip-10-0-80-194.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/d33e7c3e-3dd1-44e3-a8c0-35a73b5341ef', 'DMLC_ROLE': 'scheduler', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:338414223723:training-job/kmeans-2020-05-27-02-56-51-195', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [05/27/2020 02:59:37 INFO 140049757583168] Launching parameter server for role server
# [05/27/2020 02:59:37 INFO 140049757583168] {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/393acab1-4b1a-4ea1-8367-949922e9f99d', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/393acab1-4b1a-4ea1-8367-949922e9f99d', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'AWS_REGION': 'us-east-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'kmeans-2020-05-27-02-56-51-195', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '18', 'HOSTNAME': 'ip-10-0-80-194.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/d33e7c3e-3dd1-44e3-a8c0-35a73b5341ef', 'PWD': '/', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:338414223723:training-job/kmeans-2020-05-27-02-56-51-195', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [05/27/2020 02:59:37 INFO 140049757583168] envs={'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/393acab1-4b1a-4ea1-8367-949922e9f99d', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/393acab1-4b1a-4ea1-8367-949922e9f99d', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_NUM_WORKER': '2', 'DMLC_PS_ROOT_PORT': '9000', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'SAGEMAKER_HTTP_PORT': '8080', 'HOME': '/root', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.80.194', 'AWS_REGION': 'us-east-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'kmeans-2020-05-27-02-56-51-195', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '18', 'HOSTNAME': 'ip-10-0-80-194.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/d33e7c3e-3dd1-44e3-a8c0-35a73b5341ef', 'DMLC_ROLE': 'server', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:338414223723:training-job/kmeans-2020-05-27-02-56-51-195', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# [05/27/2020 02:59:37 INFO 140049757583168] Environment: {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/393acab1-4b1a-4ea1-8367-949922e9f99d', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/393acab1-4b1a-4ea1-8367-949922e9f99d', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_WORKER': '2', 'SAGEMAKER_HTTP_PORT': '8080', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.80.194', 'AWS_REGION': 'us-east-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'kmeans-2020-05-27-02-56-51-195', 'HOME': '/root', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '18', 'HOSTNAME': 'ip-10-0-80-194.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/d33e7c3e-3dd1-44e3-a8c0-35a73b5341ef', 'DMLC_ROLE': 'worker', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:338414223723:training-job/kmeans-2020-05-27-02-56-51-195', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# Process 108 is a shell:scheduler.
# Process 117 is a shell:server.
# Process 1 is a worker.
# [05/27/2020 02:59:37 INFO 140049757583168] Using default worker.
# [05/27/2020 02:59:37 INFO 140049757583168] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [05/27/2020 02:59:37 INFO 140049757583168] Create Store: dist_async
# [05/27/2020 02:59:38 INFO 140049757583168] nvidia-smi took: 0.0252871513367 secs to identify 0 gpus
# [05/27/2020 02:59:38 INFO 140049757583168] Number of GPUs being used: 0
# [05/27/2020 02:59:38 INFO 140049757583168] Setting up with params: {u'_tuning_objective_metric': u'', u'extra_center_factor': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'True', u'epochs': u'100', u'feature_dim': u'784', u'local_lloyd_tol': u'0.0001', u'_disable_wait_to_read': u'false', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'_enable_profiler': u'false', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'init_method': u'random', u'half_life_time_size': u'0', u'local_lloyd_max_iter': u'300', u'_kvstore': u'auto', u'k': u'10', u'_num_slices': u'1'}
# [05/27/2020 02:59:38 INFO 140049757583168] 'extra_center_factor' was set to 'auto', evaluated to 10.
# [05/27/2020 02:59:38 INFO 140049757583168] Number of GPUs being used: 0
# [05/27/2020 02:59:38 INFO 140049757583168] number of center slices 1
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Records Since Last Reset": {"count": 1, "max": 5000, "sum": 5000.0, "min": 5000}, "Total Batches Seen": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Total Records Seen": {"count": 1, "max": 5000, "sum": 5000.0, "min": 5000}, "Max Records Seen Between Resets": {"count": 1, "max": 5000, "sum": 5000.0, "min": 5000}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1590548378.360684, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1590548378.360648}
#
# [2020-05-27 02:59:38.382] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 91, "num_examples": 1, "num_bytes": 15820000}
# [2020-05-27 02:59:38.583] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 200, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:38 INFO 140049757583168] processed a total of 25000 examples
# [05/27/2020 02:59:38 INFO 140049757583168] #progress_metric: host=algo-1, completed 1 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 6, "sum": 6.0, "min": 6}, "Total Records Seen": {"count": 1, "max": 30000, "sum": 30000.0, "min": 30000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1590548378.58415, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 0}, "StartTime": 1590548378.382794}
#
# [05/27/2020 02:59:38 INFO 140049757583168] #throughput_metric: host=algo-1, train throughput=124051.022267 records/second
# [2020-05-27 02:59:38.726] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 140, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:38 INFO 140049757583168] processed a total of 25000 examples
# [05/27/2020 02:59:38 INFO 140049757583168] #progress_metric: host=algo-1, completed 2 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Total Records Seen": {"count": 1, "max": 55000, "sum": 55000.0, "min": 55000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1590548378.727451, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 1}, "StartTime": 1590548378.584414}
#
# [05/27/2020 02:59:38 INFO 140049757583168] #throughput_metric: host=algo-1, train throughput=174577.323741 records/second
# 2020-05-27 02:59:33 Training - Training image download completed. Training in progress.Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [05/27/2020 02:59:36 INFO 140108046878528] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-input.json: {u'_enable_profiler': u'false', u'_tuning_objective_metric': u'', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'_kvstore': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'true', u'epochs': u'1', u'init_method': u'random', u'local_lloyd_tol': u'0.0001', u'local_lloyd_max_iter': u'300', u'_disable_wait_to_read': u'false', u'extra_center_factor': u'auto', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'half_life_time_size': u'0', u'_num_slices': u'1'}
# [05/27/2020 02:59:36 INFO 140108046878528] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'epochs': u'100', u'feature_dim': u'784', u'k': u'10', u'force_dense': u'True'}
# [05/27/2020 02:59:36 INFO 140108046878528] Final configuration: {u'_tuning_objective_metric': u'', u'extra_center_factor': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'True', u'epochs': u'100', u'feature_dim': u'784', u'local_lloyd_tol': u'0.0001', u'_disable_wait_to_read': u'false', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'_enable_profiler': u'false', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'init_method': u'random', u'half_life_time_size': u'0', u'local_lloyd_max_iter': u'300', u'_kvstore': u'auto', u'k': u'10', u'_num_slices': u'1'}
# [05/27/2020 02:59:36 WARNING 140108046878528] Loggers have already been setup.
# [05/27/2020 02:59:36 INFO 140108046878528] Environment: {'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/36ec2497-fef9-4631-8ea8-b4b35a01a2f0', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/36ec2497-fef9-4631-8ea8-b4b35a01a2f0', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION_VERSION': '2', 'DMLC_PS_ROOT_PORT': '9000', 'DMLC_NUM_WORKER': '2', 'SAGEMAKER_HTTP_PORT': '8080', 'PATH': '/opt/amazon/bin:/usr/local/nvidia/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/opt/amazon/bin:/opt/amazon/bin', 'PYTHONUNBUFFERED': 'TRUE', 'CANONICAL_ENVROOT': '/opt/amazon', 'LD_LIBRARY_PATH': '/opt/amazon/lib/python2.7/site-packages/cv2/../../../../lib:/usr/local/nvidia/lib64:/opt/amazon/lib', 'MXNET_KVSTORE_BIGARRAY_BOUND': '400000000', 'LANG': 'en_US.utf8', 'DMLC_INTERFACE': 'eth0', 'SHLVL': '1', 'DMLC_PS_ROOT_URI': '10.0.80.194', 'AWS_REGION': 'us-east-2', 'SAGEMAKER_METRICS_DIRECTORY': '/opt/ml/output/metrics/sagemaker', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'kmeans-2020-05-27-02-56-51-195', 'HOME': '/root', 'PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION': 'cpp', 'ENVROOT': '/opt/amazon', 'SAGEMAKER_DATA_PATH': '/opt/ml', 'NVIDIA_DRIVER_CAPABILITIES': 'compute,utility', 'NVIDIA_REQUIRE_CUDA': 'cuda>=9.0', 'OMP_NUM_THREADS': '18', 'HOSTNAME': 'ip-10-0-89-56.us-east-2.compute.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/d850dc0b-9736-4091-a81d-2f66c9c8ff97', 'DMLC_ROLE': 'worker', 'PWD': '/', 'DMLC_NUM_SERVER': '1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-2:338414223723:training-job/kmeans-2020-05-27-02-56-51-195', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2'}
# Process 1 is a worker.
# [05/27/2020 02:59:36 INFO 140108046878528] Using default worker.
# [05/27/2020 02:59:36 INFO 140108046878528] Loaded iterator creator application/x-recordio-protobuf for content type ('application/x-recordio-protobuf', '1.0')
# [05/27/2020 02:59:36 INFO 140108046878528] Create Store: dist_async
# [05/27/2020 02:59:38 INFO 140108046878528] nvidia-smi took: 0.0252120494843 secs to identify 0 gpus
# [05/27/2020 02:59:38 INFO 140108046878528] Number of GPUs being used: 0
# [05/27/2020 02:59:38 INFO 140108046878528] Setting up with params: {u'_tuning_objective_metric': u'', u'extra_center_factor': u'auto', u'local_lloyd_init_method': u'kmeans++', u'force_dense': u'True', u'epochs': u'100', u'feature_dim': u'784', u'local_lloyd_tol': u'0.0001', u'_disable_wait_to_read': u'false', u'eval_metrics': u'["msd"]', u'_num_kv_servers': u'1', u'mini_batch_size': u'5000', u'_enable_profiler': u'false', u'_num_gpus': u'auto', u'local_lloyd_num_trials': u'auto', u'_log_level': u'info', u'init_method': u'random', u'half_life_time_size': u'0', u'local_lloyd_max_iter': u'300', u'_kvstore': u'auto', u'k': u'10', u'_num_slices': u'1'}
# [05/27/2020 02:59:38 INFO 140108046878528] 'extra_center_factor' was set to 'auto', evaluated to 10.
# [05/27/2020 02:59:38 INFO 140108046878528] Number of GPUs being used: 0
# [05/27/2020 02:59:38 INFO 140108046878528] number of center slices 1
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Records Since Last Reset": {"count": 1, "max": 5000, "sum": 5000.0, "min": 5000}, "Total Batches Seen": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Total Records Seen": {"count": 1, "max": 5000, "sum": 5000.0, "min": 5000}, "Max Records Seen Between Resets": {"count": 1, "max": 5000, "sum": 5000.0, "min": 5000}, "Reset Count": {"count": 1, "max": 0, "sum": 0.0, "min": 0}}, "EndTime": 1590548378.359823, "Dimensions": {"Host": "algo-2", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1590548378.35979}
#
# [2020-05-27 02:59:38.375] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 86, "num_examples": 1, "num_bytes": 15820000}
# [2020-05-27 02:59:38.553] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 1, "duration": 178, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:38 INFO 140108046878528] processed a total of 25000 examples
# [05/27/2020 02:59:38 INFO 140108046878528] #progress_metric: host=algo-2, completed 1 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 6, "sum": 6.0, "min": 6}, "Total Records Seen": {"count": 1, "max": 30000, "sum": 30000.0, "min": 30000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1590548378.554432, "Dimensions": {"Host": "algo-2", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 0}, "StartTime": 1590548378.375513}
#
# [05/27/2020 02:59:38 INFO 140108046878528] #throughput_metric: host=algo-2, train throughput=139622.666633 records/second
# [2020-05-27 02:59:38.673] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 3, "duration": 119, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:38 INFO 140108046878528] processed a total of 25000 examples
# [05/27/2020 02:59:38 INFO 140108046878528] #progress_metric: host=algo-2, completed 2 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 11, "sum": 11.0, "min": 11}, "Total Records Seen": {"count": 1, "max": 55000, "sum": 55000.0, "min": 55000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1590548378.674366, "Dimensions": {"Host": "algo-2", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 1}, "StartTime": 1590548378.554677}
#
# [05/27/2020 02:59:38 INFO 140108046878528] #throughput_metric: host=algo-2, train throughput=208679.315876 records/second
# [2020-05-27 02:59:38.800] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 124, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:38 INFO 140108046878528] processed a total of 25000 examples
# [05/27/2020 02:59:38 INFO 140108046878528] #progress_metric: host=algo-2, completed 3 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 16, "sum": 16.0, "min": 16}, "Total Records Seen": {"count": 1, "max": 80000, "sum": 80000.0, "min": 80000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1590548378.801144, "Dimensions": {"Host": "algo-2", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 2}, "StartTime": 1590548378.674572}
#
# [05/27/2020 02:59:38 INFO 140108046878528] #throughput_metric: host=algo-2, train throughput=197297.678698 records/second
# [2020-05-27 02:59:38.917] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 115, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:38 INFO 140108046878528] processed a total of 25000 examples
# [05/27/2020 02:59:38 INFO 140108046878528] #progress_metric: host=algo-2, completed 4 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 21, "sum": 21.0, "min": 21}, "Total Records Seen": {"count": 1, "max": 105000, "sum": 105000.0, "min": 105000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1590548378.917994, "Dimensions": {"Host": "algo-2", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 3}, "StartTime": 1590548378.801448}
#
# [05/27/2020 02:59:38 INFO 140108046878528] #throughput_metric: host=algo-2, train throughput=214250.015835 records/second
# [2020-05-27 02:59:39.034] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 115, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:39 INFO 140108046878528] processed a total of 25000 examples
# [05/27/2020 02:59:39 INFO 140108046878528] #progress_metric: host=algo-2, completed 5 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 26, "sum": 26.0, "min": 26}, "Total Records Seen": {"count": 1, "max": 130000, "sum": 130000.0, "min": 130000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1590548379.034756, "Dimensions": {"Host": "algo-2", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 4}, "StartTime": 1590548378.918249}
#
# [05/27/2020 02:59:39 INFO 140108046878528] #throughput_metric: host=algo-2, train throughput=214332.785531 records/second
# [2020-05-27 02:59:39.143] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 11, "duration": 108, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:39 INFO 140108046878528] processed a total of 25000 examples
# [05/27/2020 02:59:39 INFO 140108046878528] #progress_metric: host=algo-2, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 31, "sum": 31.0, "min": 31}, "Total Records Seen": {"count": 1, "max": 155000, "sum": 155000.0, "min": 155000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 6, "sum": 6.0, "min": 6}}, "EndTime": 1590548379.143998, "Dimensions": {"Host": "algo-2", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 5}, "StartTime": 1590548379.034994}
#
# [05/27/2020 02:59:39 INFO 140108046878528] #throughput_metric: host=algo-2, train throughput=229057.252517 records/second
# [2020-05-27 02:59:38.829] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 5, "duration": 101, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:38 INFO 140049757583168] processed a total of 25000 examples
# [05/27/2020 02:59:38 INFO 140049757583168] #progress_metric: host=algo-1, completed 3 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 16, "sum": 16.0, "min": 16}, "Total Records Seen": {"count": 1, "max": 80000, "sum": 80000.0, "min": 80000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 3, "sum": 3.0, "min": 3}}, "EndTime": 1590548378.830035, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 2}, "StartTime": 1590548378.727847}
#
# [05/27/2020 02:59:38 INFO 140049757583168] #throughput_metric: host=algo-1, train throughput=244315.105198 records/second
# [2020-05-27 02:59:38.956] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 7, "duration": 126, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:38 INFO 140049757583168] processed a total of 25000 examples
# [05/27/2020 02:59:38 INFO 140049757583168] #progress_metric: host=algo-1, completed 4 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 21, "sum": 21.0, "min": 21}, "Total Records Seen": {"count": 1, "max": 105000, "sum": 105000.0, "min": 105000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 4, "sum": 4.0, "min": 4}}, "EndTime": 1590548378.956969, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 3}, "StartTime": 1590548378.830329}
#
# [05/27/2020 02:59:38 INFO 140049757583168] #throughput_metric: host=algo-1, train throughput=197179.3271 records/second
# [2020-05-27 02:59:39.077] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 9, "duration": 120, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:39 INFO 140049757583168] processed a total of 25000 examples
# [05/27/2020 02:59:39 INFO 140049757583168] #progress_metric: host=algo-1, completed 5 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 26, "sum": 26.0, "min": 26}, "Total Records Seen": {"count": 1, "max": 130000, "sum": 130000.0, "min": 130000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 5, "sum": 5.0, "min": 5}}, "EndTime": 1590548379.078329, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 4}, "StartTime": 1590548378.957393}
#
# [05/27/2020 02:59:39 INFO 140049757583168] #throughput_metric: host=algo-1, train throughput=206473.565029 records/second
# [2020-05-27 02:59:39.191] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 11, "duration": 113, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:39 INFO 140049757583168] processed a total of 25000 examples
# [05/27/2020 02:59:39 INFO 140049757583168] #progress_metric: host=algo-1, completed 6 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 31, "sum": 31.0, "min": 31}, "Total Records Seen": {"count": 1, "max": 155000, "sum": 155000.0, "min": 155000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 6, "sum": 6.0, "min": 6}}, "EndTime": 1590548379.192562, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 5}, "StartTime": 1590548379.078579}
#
# [05/27/2020 02:59:39 INFO 140049757583168] #throughput_metric: host=algo-1, train throughput=219065.804813 records/second
# [2020-05-27 02:59:39.312] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 13, "duration": 119, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:39 INFO 140049757583168] processed a total of 25000 examples
# [05/27/2020 02:59:39 INFO 140049757583168] #progress_metric: host=algo-1, completed 7 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 36, "sum": 36.0, "min": 36}, "Total Records Seen": {"count": 1, "max": 180000, "sum": 180000.0, "min": 180000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 7, "sum": 7.0, "min": 7}}, "EndTime": 1590548379.313015, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 6}, "StartTime": 1590548379.19281}
#
# [05/27/2020 02:59:39 INFO 140049757583168] #throughput_metric: host=algo-1, train throughput=207743.300591 records/second
# [2020-05-27 02:59:39.439] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 15, "duration": 124, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:39 INFO 140049757583168] processed a total of 25000 examples
# [05/27/2020 02:59:39 INFO 140049757583168] #progress_metric: host=algo-1, completed 8 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 41, "sum": 41.0, "min": 41}, "Total Records Seen": {"count": 1, "max": 205000, "sum": 205000.0, "min": 205000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 8, "sum": 8.0, "min": 8}}, "EndTime": 1590548379.439778, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 7}, "StartTime": 1590548379.313262}
#
# [05/27/2020 02:59:39 INFO 140049757583168] #throughput_metric: host=algo-1, train throughput=197388.300626 records/second
# [2020-05-27 02:59:39.542] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 17, "duration": 102, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:39 INFO 140049757583168] processed a total of 25000 examples
# [05/27/2020 02:59:39 INFO 140049757583168] #progress_metric: host=algo-1, completed 9 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 46, "sum": 46.0, "min": 46}, "Total Records Seen": {"count": 1, "max": 230000, "sum": 230000.0, "min": 230000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 9, "sum": 9.0, "min": 9}}, "EndTime": 1590548379.543241, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 8}, "StartTime": 1590548379.44003}
#
# [05/27/2020 02:59:39 INFO 140049757583168] #throughput_metric: host=algo-1, train throughput=241868.189661 records/second
# [2020-05-27 02:59:39.649] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 19, "duration": 105, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:39 INFO 140049757583168] processed a total of 25000 examples
# [05/27/2020 02:59:39 INFO 140049757583168] #progress_metric: host=algo-1, completed 10 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 51, "sum": 51.0, "min": 51}, "Total Records Seen": {"count": 1, "max": 255000, "sum": 255000.0, "min": 255000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1590548379.650002, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 9}, "StartTime": 1590548379.5435}
#
# [05/27/2020 02:59:39 INFO 140049757583168] #throughput_metric: host=algo-1, train throughput=234422.381299 records/second
# [2020-05-27 02:59:39.758] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 21, "duration": 107, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:39 INFO 140049757583168] processed a total of 25000 examples
# [05/27/2020 02:59:39 INFO 140049757583168] #progress_metric: host=algo-1, completed 11 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 56, "sum": 56.0, "min": 56}, "Total Records Seen": {"count": 1, "max": 280000, "sum": 280000.0, "min": 280000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 11, "sum": 11.0, "min": 11}}, "EndTime": 1590548379.75875, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 10}, "StartTime": 1590548379.650267}
#
# [05/27/2020 02:59:39 INFO 140049757583168] #throughput_metric: host=algo-1, train throughput=230128.015205 records/second
# [2020-05-27 02:59:39.256] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 13, "duration": 112, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:39 INFO 140108046878528] processed a total of 25000 examples
# [05/27/2020 02:59:39 INFO 140108046878528] #progress_metric: host=algo-2, completed 7 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 36, "sum": 36.0, "min": 36}, "Total Records Seen": {"count": 1, "max": 180000, "sum": 180000.0, "min": 180000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 7, "sum": 7.0, "min": 7}}, "EndTime": 1590548379.257269, "Dimensions": {"Host": "algo-2", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 6}, "StartTime": 1590548379.144243}
#
# [05/27/2020 02:59:39 INFO 140108046878528] #throughput_metric: host=algo-2, train throughput=220818.855321 records/second
# [2020-05-27 02:59:39.370] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 15, "duration": 112, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:39 INFO 140108046878528] processed a total of 25000 examples
# [05/27/2020 02:59:39 INFO 140108046878528] #progress_metric: host=algo-2, completed 8 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 41, "sum": 41.0, "min": 41}, "Total Records Seen": {"count": 1, "max": 205000, "sum": 205000.0, "min": 205000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 8, "sum": 8.0, "min": 8}}, "EndTime": 1590548379.37101, "Dimensions": {"Host": "algo-2", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 7}, "StartTime": 1590548379.257568}
#
# [05/27/2020 02:59:39 INFO 140108046878528] #throughput_metric: host=algo-2, train throughput=220112.892832 records/second
# [2020-05-27 02:59:39.484] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 17, "duration": 113, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:39 INFO 140108046878528] processed a total of 25000 examples
# [05/27/2020 02:59:39 INFO 140108046878528] #progress_metric: host=algo-2, completed 9 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 46, "sum": 46.0, "min": 46}, "Total Records Seen": {"count": 1, "max": 230000, "sum": 230000.0, "min": 230000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 9, "sum": 9.0, "min": 9}}, "EndTime": 1590548379.485023, "Dimensions": {"Host": "algo-2", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 8}, "StartTime": 1590548379.371258}
#
# [05/27/2020 02:59:39 INFO 140108046878528] #throughput_metric: host=algo-2, train throughput=219487.209543 records/second
# [2020-05-27 02:59:39.602] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 19, "duration": 115, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:39 INFO 140108046878528] processed a total of 25000 examples
# [05/27/2020 02:59:39 INFO 140108046878528] #progress_metric: host=algo-2, completed 10 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 51, "sum": 51.0, "min": 51}, "Total Records Seen": {"count": 1, "max": 255000, "sum": 255000.0, "min": 255000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 10, "sum": 10.0, "min": 10}}, "EndTime": 1590548379.602515, "Dimensions": {"Host": "algo-2", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 9}, "StartTime": 1590548379.486634}
#
# [05/27/2020 02:59:39 INFO 140108046878528] #throughput_metric: host=algo-2, train throughput=215487.684081 records/second
# [2020-05-27 02:59:39.718] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 21, "duration": 115, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:39 INFO 140108046878528] processed a total of 25000 examples
# [05/27/2020 02:59:39 INFO 140108046878528] #progress_metric: host=algo-2, completed 11 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 56, "sum": 56.0, "min": 56}, "Total Records Seen": {"count": 1, "max": 280000, "sum": 280000.0, "min": 280000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 11, "sum": 11.0, "min": 11}}, "EndTime": 1590548379.718575, "Dimensions": {"Host": "algo-2", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 10}, "StartTime": 1590548379.602759}
#
# [05/27/2020 02:59:39 INFO 140108046878528] #throughput_metric: host=algo-2, train throughput=215606.430096 records/second
# [2020-05-27 02:59:39.845] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 23, "duration": 124, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:39 INFO 140108046878528] processed a total of 25000 examples
# [05/27/2020 02:59:39 INFO 140108046878528] #progress_metric: host=algo-2, completed 12 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 61, "sum": 61.0, "min": 61}, "Total Records Seen": {"count": 1, "max": 305000, "sum": 305000.0, "min": 305000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 12, "sum": 12.0, "min": 12}}, "EndTime": 1590548379.845729, "Dimensions": {"Host": "algo-2", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 11}, "StartTime": 1590548379.719016}
#
# [05/27/2020 02:59:39 INFO 140108046878528] #throughput_metric: host=algo-2, train throughput=197078.524978 records/second
# [2020-05-27 02:59:39.946] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 25, "duration": 100, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:39 INFO 140108046878528] processed a total of 25000 examples
# [05/27/2020 02:59:39 INFO 140108046878528] #progress_metric: host=algo-2, completed 13 % of epochs
# ...
# [05/27/2020 02:59:50 INFO 140108046878528] collect from kv store took: 8.0101%, (0.911970 secs)
# [05/27/2020 02:59:50 INFO 140108046878528] predict compute msd took: 4.3007%, (0.489648 secs)
# [05/27/2020 02:59:50 INFO 140108046878528] gradient: cluster size  took: 2.9541%, (0.336333 secs)
# [05/27/2020 02:59:50 INFO 140108046878528] gradient: one_hot took: 1.4256%, (0.162307 secs)
# [05/27/2020 02:59:50 INFO 140108046878528] update state and report convergance took: 1.2041%, (0.137093 secs)
# [05/27/2020 02:59:50 INFO 140108046878528] compute all data-center distances: center norm took: 1.0546%, (0.120073 secs)
# [05/27/2020 02:59:50 INFO 140108046878528] splitting centers key-value pair took: 1.0328%, (0.117583 secs)
# [05/27/2020 02:59:50 INFO 140108046878528] update set-up time took: 0.1140%, (0.012983 secs)
# [05/27/2020 02:59:50 INFO 140108046878528] predict minus dist took: 0.1119%, (0.012742 secs)
# [05/27/2020 02:59:50 INFO 140108046878528] TOTAL took: 11.3852739334
# [05/27/2020 02:59:50 INFO 140108046878528] Number of GPUs being used: 0
# [05/27/2020 02:59:50 INFO 140108046878528] No model is serialized on a non-master node
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 345.42083740234375, "sum": 345.42083740234375, "min": 345.42083740234375}, "initialize.time": {"count": 1, "max": 48.38085174560547, "sum": 48.38085174560547, "min": 48.38085174560547}, "model.serialize.time": {"count": 1, "max": 0.07700920104980469, "sum": 0.07700920104980469, "min": 0.07700920104980469}, "update.time": {"count": 100, "max": 178.7400245666504, "sum": 11435.192346572876, "min": 96.55308723449707}, "epochs": {"count": 1, "max": 100, "sum": 100.0, "min": 100}, "state.serialize.time": {"count": 1, "max": 0.5719661712646484, "sum": 0.5719661712646484, "min": 0.5719661712646484}, "_shrink.time": {"count": 1, "max": 342.90003776550293, "sum": 342.90003776550293, "min": 342.90003776550293}}, "EndTime": 1590548390.210107, "Dimensions": {"Host": "algo-2", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1590548378.288296}
#
# [05/27/2020 02:59:50 INFO 140108046878528] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 14022.128105163574, "sum": 14022.128105163574, "min": 14022.128105163574}, "setuptime": {"count": 1, "max": 20.197153091430664, "sum": 20.197153091430664, "min": 20.197153091430664}}, "EndTime": 1590548390.213809, "Dimensions": {"Host": "algo-2", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1590548390.21021}
# [2020-05-27 02:59:48.824] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 187, "duration": 103, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:48 INFO 140049757583168] processed a total of 25000 examples
# [05/27/2020 02:59:48 INFO 140049757583168] #progress_metric: host=algo-1, completed 94 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 471, "sum": 471.0, "min": 471}, "Total Records Seen": {"count": 1, "max": 2355000, "sum": 2355000.0, "min": 2355000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 94, "sum": 94.0, "min": 94}}, "EndTime": 1590548388.824653, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 93}, "StartTime": 1590548388.720718}
#
# [05/27/2020 02:59:48 INFO 140049757583168] #throughput_metric: host=algo-1, train throughput=240234.604106 records/second
# [2020-05-27 02:59:48.923] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 189, "duration": 97, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:48 INFO 140049757583168] processed a total of 25000 examples
# [05/27/2020 02:59:48 INFO 140049757583168] #progress_metric: host=algo-1, completed 95 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 476, "sum": 476.0, "min": 476}, "Total Records Seen": {"count": 1, "max": 2380000, "sum": 2380000.0, "min": 2380000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 95, "sum": 95.0, "min": 95}}, "EndTime": 1590548388.923627, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 94}, "StartTime": 1590548388.824903}
#
# [05/27/2020 02:59:48 INFO 140049757583168] #throughput_metric: host=algo-1, train throughput=252545.989663 records/second
# [2020-05-27 02:59:49.029] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 191, "duration": 103, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:49 INFO 140049757583168] processed a total of 25000 examples
# [05/27/2020 02:59:49 INFO 140049757583168] #progress_metric: host=algo-1, completed 96 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 481, "sum": 481.0, "min": 481}, "Total Records Seen": {"count": 1, "max": 2405000, "sum": 2405000.0, "min": 2405000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 96, "sum": 96.0, "min": 96}}, "EndTime": 1590548389.030471, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 95}, "StartTime": 1590548388.924067}
#
# [05/27/2020 02:59:49 INFO 140049757583168] #throughput_metric: host=algo-1, train throughput=234625.37619 records/second
# [2020-05-27 02:59:49.130] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 193, "duration": 99, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:49 INFO 140049757583168] processed a total of 25000 examples
# [05/27/2020 02:59:49 INFO 140049757583168] #progress_metric: host=algo-1, completed 97 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 486, "sum": 486.0, "min": 486}, "Total Records Seen": {"count": 1, "max": 2430000, "sum": 2430000.0, "min": 2430000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 97, "sum": 97.0, "min": 97}}, "EndTime": 1590548389.13098, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 96}, "StartTime": 1590548389.030728}
#
# [05/27/2020 02:59:49 INFO 140049757583168] #throughput_metric: host=algo-1, train throughput=249014.108589 records/second
# [2020-05-27 02:59:49.253] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 195, "duration": 120, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:49 INFO 140049757583168] processed a total of 25000 examples
# [05/27/2020 02:59:49 INFO 140049757583168] #progress_metric: host=algo-1, completed 98 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 491, "sum": 491.0, "min": 491}, "Total Records Seen": {"count": 1, "max": 2455000, "sum": 2455000.0, "min": 2455000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 98, "sum": 98.0, "min": 98}}, "EndTime": 1590548389.254178, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 97}, "StartTime": 1590548389.131234}
#
# [05/27/2020 02:59:49 INFO 140049757583168] #throughput_metric: host=algo-1, train throughput=203086.851346 records/second
# [2020-05-27 02:59:49.353] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 197, "duration": 97, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:49 INFO 140049757583168] processed a total of 25000 examples
# [05/27/2020 02:59:49 INFO 140049757583168] #progress_metric: host=algo-1, completed 99 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 496, "sum": 496.0, "min": 496}, "Total Records Seen": {"count": 1, "max": 2480000, "sum": 2480000.0, "min": 2480000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 99, "sum": 99.0, "min": 99}}, "EndTime": 1590548389.353898, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 98}, "StartTime": 1590548389.254663}
#
# [05/27/2020 02:59:49 INFO 140049757583168] #throughput_metric: host=algo-1, train throughput=251519.200186 records/second
# [2020-05-27 02:59:49.473] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 199, "duration": 118, "num_examples": 5, "num_bytes": 79100000}
# [05/27/2020 02:59:49 INFO 140049757583168] processed a total of 25000 examples
# [05/27/2020 02:59:49 INFO 140049757583168] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Batches Since Last Reset": {"count": 1, "max": 5, "sum": 5.0, "min": 5}, "Number of Records Since Last Reset": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Total Batches Seen": {"count": 1, "max": 501, "sum": 501.0, "min": 501}, "Total Records Seen": {"count": 1, "max": 2505000, "sum": 2505000.0, "min": 2505000}, "Max Records Seen Between Resets": {"count": 1, "max": 25000, "sum": 25000.0, "min": 25000}, "Reset Count": {"count": 1, "max": 100, "sum": 100.0, "min": 100}}, "EndTime": 1590548389.474301, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "AWS/KMeansWebscale", "epoch": 99}, "StartTime": 1590548389.354177}
#
# [05/27/2020 02:59:49 INFO 140049757583168] #throughput_metric: host=algo-1, train throughput=207520.463577 records/second
# [05/27/2020 02:59:49 INFO 140049757583168] shrinking 100 centers into 10
# [05/27/2020 02:59:49 INFO 140049757583168] local kmeans attempt #0. Current mean square distance 12.150414
# [05/27/2020 02:59:49 INFO 140049757583168] local kmeans attempt #1. Current mean square distance 12.730486
# [05/27/2020 02:59:49 INFO 140049757583168] local kmeans attempt #2. Current mean square distance 11.890771
# [05/27/2020 02:59:50 INFO 140049757583168] local kmeans attempt #3. Current mean square distance 11.971507
# [05/27/2020 02:59:50 INFO 140049757583168] local kmeans attempt #4. Current mean square distance 11.675175
# [05/27/2020 02:59:50 INFO 140049757583168] local kmeans attempt #5. Current mean square distance 11.734095
# [05/27/2020 02:59:50 INFO 140049757583168] local kmeans attempt #6. Current mean square distance 11.885342
# [05/27/2020 02:59:50 INFO 140049757583168] local kmeans attempt #7. Current mean square distance 11.618146
# [05/27/2020 02:59:50 INFO 140049757583168] local kmeans attempt #8. Current mean square distance 11.960022
# [05/27/2020 02:59:50 INFO 140049757583168] local kmeans attempt #9. Current mean square distance 11.597189
# [05/27/2020 02:59:50 INFO 140049757583168] finished shrinking process. Mean Square Distance = 12
# [05/27/2020 02:59:50 INFO 140049757583168] #quality_metric: host=algo-1, train msd <loss>=11.5971889496
# [05/27/2020 02:59:50 INFO 140049757583168] batch data loading with context took: 38.1039%, (4.214660 secs)
# [05/27/2020 02:59:50 INFO 140049757583168] compute all data-center distances: point norm took: 19.5030%, (2.157218 secs)
# [05/27/2020 02:59:50 INFO 140049757583168] gradient: cluster center took: 12.6439%, (1.398531 secs)
# [05/27/2020 02:59:50 INFO 140049757583168] compute all data-center distances: inner product took: 9.5430%, (1.055545 secs)
# [05/27/2020 02:59:50 INFO 140049757583168] collect from kv store took: 5.5921%, (0.618543 secs)
# [05/27/2020 02:59:50 INFO 140049757583168] predict compute msd took: 4.7584%, (0.526321 secs)
# [05/27/2020 02:59:50 INFO 140049757583168] gradient: cluster size  took: 3.2183%, (0.355974 secs)
# [05/27/2020 02:59:50 INFO 140049757583168] splitting centers key-value pair took: 1.8688%, (0.206711 secs)
# [05/27/2020 02:59:50 INFO 140049757583168] compute all data-center distances: center norm took: 1.7445%, (0.192954 secs)
# [05/27/2020 02:59:50 INFO 140049757583168] gradient: one_hot took: 1.5148%, (0.167557 secs)
# [05/27/2020 02:59:50 INFO 140049757583168] update state and report convergance took: 1.2681%, (0.140269 secs)
# [05/27/2020 02:59:50 INFO 140049757583168] update set-up time took: 0.1268%, (0.014024 secs)
# [05/27/2020 02:59:50 INFO 140049757583168] predict minus dist took: 0.1144%, (0.012650 secs)
# [05/27/2020 02:59:50 INFO 140049757583168] TOTAL took: 11.0609562397
# [05/27/2020 02:59:50 INFO 140049757583168] Number of GPUs being used: 0
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 364.2010688781738, "sum": 364.2010688781738, "min": 364.2010688781738}, "initialize.time": {"count": 1, "max": 45.081138610839844, "sum": 45.081138610839844, "min": 45.081138610839844}, "model.serialize.time": {"count": 1, "max": 0.20003318786621094, "sum": 0.20003318786621094, "min": 0.20003318786621094}, "update.time": {"count": 100, "max": 201.15900039672852, "sum": 11037.816524505615, "min": 95.51596641540527}, "epochs": {"count": 1, "max": 100, "sum": 100.0, "min": 100}, "state.serialize.time": {"count": 1, "max": 0.5049705505371094, "sum": 0.5049705505371094, "min": 0.5049705505371094}, "_shrink.time": {"count": 1, "max": 362.0731830596924, "sum": 362.0731830596924, "min": 362.0731830596924}}, "EndTime": 1590548390.229861, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1590548378.290406}
#
# [05/27/2020 02:59:50 INFO 140049757583168] Test data is not provided.
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 13115.343809127808, "sum": 13115.343809127808, "min": 13115.343809127808}, "setuptime": {"count": 1, "max": 26.295900344848633, "sum": 26.295900344848633, "min": 26.295900344848633}}, "EndTime": 1590548390.233952, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "AWS/KMeansWebscale"}, "StartTime": 1590548390.229972}
# 2020-05-27 03:00:02 Uploading - Uploading generated training model
# 2020-05-27 03:00:02 Completed - Training job completed
# Training seconds: 150
# Billable seconds: 150
# CPU times: user 8.54 s, sys: 437 ms, total: 8.98 s
# Wall time: 3min 52s

# %%
# %%time
#deploy the model to make predictions

kmeans_predictor = kmeans.deploy(initial_instance_count=1,
                                 instance_type='ml.m4.xlarge')
# Out:
# ---------------!CPU times: user 255 ms, sys: 25.8 ms, total: 280 ms
# Wall time: 7min 32s

# %%
# %%time 

result = kmeans_predictor.predict(valid_set[0][0:100])
clusters = [r.label['closest_cluster'].float32_tensor.values[0] for r in result]
# Out:
# CPU times: user 34.6 ms, sys: 498 µs, total: 35.1 ms
# Wall time: 250 ms

# %%
for cluster in range(10):
    print('\n\n\nCluster {}:'.format(int(cluster)))
    digits = [ img for l, img in zip(clusters, valid_set[0]) if int(l) == cluster ]
    height = ((len(digits)-1)//5) + 1
    width = 5
    plt.rcParams["figure.figsize"] = (width,height)
    _, subplots = plt.subplots(height, width)
    subplots = numpy.ndarray.flatten(subplots)
    for subplot, image in zip(subplots, digits):
        show_digit(image, subplot=subplot)
    for subplot in subplots[len(digits):]:
        subplot.axis('off')

    plt.show()
# Out:
# Cluster 0:
# Cluster 1:
# Cluster 2:
# Cluster 3:
# Cluster 4:
# Cluster 5:
# Cluster 6:
# Cluster 7:
# Cluster 8:
# Cluster 9:

# %%
result = kmeans_predictor.predict(valid_set[0][235:236])
print(result)
# Out:
# [label {
#   key: "closest_cluster"
#   value {
#     float32_tensor {
#       values: 9.0
#     }
#   }
# }
# label {
#   key: "distance_to_cluster"
#   value {
#     float32_tensor {
#       values: 6.5558271408081055
#     }
#   }
# }
# ]

# %%
show_digit(valid_set[0][235], 'This is a {}'.format(valid_set[1][235]))
